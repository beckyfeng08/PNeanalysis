# %%
# %matplotlib inline
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize
import math

# %%
fits_file = 'https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:TESS/product/tess2020212050318-s0028-0000000069813909-0190-s_lc.fits'

# %%
fits.info(fits_file)
# Out:
# Filename: /Users/rebsters/.astropy/cache/download/url/0b2b33fac312d7cbf10d32dbd01d4562/contents
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  LIGHTCURVE    1 BinTableHDU    167   18182R x 20C   [D, E, J, E, E, E, E, E, E, J, D, E, D, E, D, E, D, E, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 11)   int32

# %%
fits.getdata(fits_file, ext=1).columns
# Out:
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 'BJD - 2457000, days'; disp = 'D14.7'
#     name = 'TIMECORR'; format = 'E'; unit = 'd'; disp = 'E14.7'
#     name = 'CADENCENO'; format = 'J'; disp = 'I10'
#     name = 'SAP_FLUX'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_FLUX_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_BKG'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_BKG_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'PDCSAP_FLUX'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'PDCSAP_FLUX_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'QUALITY'; format = 'J'; disp = 'B16.16'
#     name = 'PSF_CENTR1'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'PSF_CENTR1_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'PSF_CENTR2'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'PSF_CENTR2_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'MOM_CENTR1'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'MOM_CENTR1_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'MOM_CENTR2'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'MOM_CENTR2_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'POS_CORR1'; format = 'E'; unit = 'pixels'; disp = 'E14.7'
#     name = 'POS_CORR2'; format = 'E'; unit = 'pixels'; disp = 'E14.7'
# )

# %%
with fits.open(fits_file, mode="readonly") as hdulist:
    tess_bjds = hdulist[1].data['TIME']
    sap_fluxes = hdulist[1].data['SAP_FLUX']
    pdcsap_fluxes = hdulist[1].data['PDCSAP_FLUX']
pdcsap_fluxes_nonan = np.array([]) 
tess_bjds_nonan = np.array([]) 
for i in range(len(pdcsap_fluxes)):
    if (not math.isnan(pdcsap_fluxes[i])):
        pdcsap_fluxes_nonan = np.append(pdcsap_fluxes_nonan, [pdcsap_fluxes[i]])
        tess_bjds_nonan = np.append(tess_bjds_nonan, [tess_bjds[i]])
# Out:
# [463.71606445 458.60113525 462.89379883 ... 496.19979858 479.3006897
#  475.89266968] [2061.85621843 2061.85760737 2061.85899631 ... 2084.72607638 2084.72746527
#  2084.72885416]

# %%
def sin(x, a, b, c):
    return a * np.sin(b * x)+c
params, params_covariance = optimize.curve_fit(sin, tess_bjds_nonan, pdcsap_fluxes_nonan/500)

print(params)
# Out:
# [-3.29699795e-04  1.00038826e+00  9.33104105e-01]

# %%
# Define the epoch of primary transit in TBJD.  Our timestamps are also already in TBJD.
#t0 = 2037.895
t0 = 2067

# Start figure and axis.
fig, ax = plt.subplots()

# Plot the timeseries in black circles.
ax.plot(tess_bjds_nonan, pdcsap_fluxes_nonan/500, 'ko', markersize = '0.5')

# Center the x-axis on where we expect a transit to be (time = T0), and set
# the x-axis range within +/- 1 day of T0.
ax.set_xlim(t0 - 4, t0 + 4)
ax.set_ylim(0.9, 0.98)

# Let's label the axes and define a title for the figure.
fig.suptitle("NGC 7293 Light Curve")
ax.set_ylabel("PDCSAP Flux (e-/s)")
ax.set_xlabel("Time (TBJD)")

ax.plot(np.linspace(2063, 2071, 100), sin(np.linspace(2063, 2071, 100), 0.005, params[1], params[2]))
# Adjust the left margin so the y-axis label shows up.
plt.subplots_adjust(left=0.15)
plt.show()

# %%
with fits.open(fits_file, mode="readonly") as hdulist:
    aperture = hdulist[2].data

# %%
# Start figure and axis.
fig, ax = plt.subplots()

# Display the pixels as an image.
cax = ax.imshow(aperture, cmap=plt.cm.YlGnBu_r, origin="lower")

# Add a color bar.
cbar = fig.colorbar(cax)

# Add a title to the plot.
fig.suptitle("NGC 246 Aperture - Sector 1")
plt.show()
